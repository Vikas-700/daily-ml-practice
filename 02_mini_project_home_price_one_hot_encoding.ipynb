# %%
# importing important library
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# load Data Set
df=pd.read_csv("home_price.csv")

# %%
# Check Data
df.head()
# Out:
#   locality  area_sqr_ft  price_lakhs  bedrooms
# 0   Kollur          656         39.0         2
# 1   Kollur         1260         83.2         2
# 2   Kollur         1057         86.6         3
# 3   Kollur         1259         59.0         2
# 4   Kollur         1800        140.0         3

# %%
# perform one-hot encoding
pd.get_dummies(df,columns=['locality'])
# Out:
#     area_sqr_ft  price_lakhs  bedrooms  locality_Banjara Hills  \
# 0           656         39.0         2                   False
# 1          1260         83.2         2                   False
# 2          1057         86.6         3                   False
# 3          1259         59.0         2                   False
# 4          1800        140.0         3                   False
# 5          1325         80.1         2                   False
# 6          1085        116.0         3                   False
# 7          1110         45.0         2                   False
# 8          1700        100.0         3                   False
# 9          1650        200.0         3                    True
# 10         2438        316.0         3                    True
# 11         2115        220.0         2                    True
# 12         1600        150.0         3                    True
# 13         2400        300.0         3                    True
# ...

# %%
#save encoded data with remove extra column
encoded_data=pd.get_dummies(df,columns=['locality'],drop_first=True)

# %%
# show Encoded Data
encoded_data.head()
# Out:
#    area_sqr_ft  price_lakhs  bedrooms  locality_Kollur  locality_Mankhal
# 0          656         39.0         2             True             False
# 1         1260         83.2         2             True             False
# 2         1057         86.6         3             True             False
# 3         1259         59.0         2             True             False
# 4         1800        140.0         3             True             False

# %%
# split feature Data 
X=encoded_data.drop('price_lakhs',axis=1)

# %%
# split label Data
y=encoded_data[['price_lakhs']]

# %%
# spilt data into Two part for traing and testing
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
# define model
ml=LinearRegression()

# %%
# train model on training data
ml.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predict on test data
y_pred=ml.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 # predict on test data
# ----> 2 y_pred=ml.predict(X_test)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:335, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
# --> 335     check_is_fitted(self)
#     337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
# check acuraccy of model prediction
r2_score(y_test,y_pred)
# Out:
# 0.8558905263155381
